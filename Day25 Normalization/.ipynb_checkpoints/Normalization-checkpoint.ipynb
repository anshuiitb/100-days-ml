# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/users/Anshu/100-days-ml/placement.csv" , index_col=0)
data.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df = pd.read_csv("wine_data.csv", header=None , usecols = [0,1,2])
df.columns=["Class label","Alcohol","Malic acid"]
df.sample(5)
# Out:
#      Class label  Alcohol  Malic acid
# 165            3    13.73        4.36
# 19             1    13.64        3.10
# 6              1    14.39        1.87
# 157            3    12.45        3.03
# 25             1    13.05        2.05

# %% [markdown]
# <h2>MinMax</h2>

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Alcohol'], fill=True, label='Alcohol')
sns.kdeplot(df['Malic acid'], fill=True, label='Malic acid')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(df.iloc[: ,1:] , df.iloc[: , 0], test_size = 0.3 , random_state=0)

# %%
X_train.shape , X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled , columns = X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled , columns = X_train.columns)

# %%
X_train_scaled , X_test_scaled
# Out:
# (      Alcohol  Malic acid
#  0    0.720430    0.203782
#  1    0.319892    0.084034
#  2    0.602151    0.712185
#  3    0.572581    0.563025
#  4    0.760753    0.130252
#  ..        ...         ...
#  119  0.212366    0.174370
#  120  0.360215    0.058824
#  121  0.373656    0.151261
#  122  0.771505    0.165966
#  123  0.841398    0.340336
#
#  [124 rows x 2 columns],
#       Alcohol  Malic acid
#  0   0.728495    0.163866
#  1   0.473118    0.373950
#  2   0.360215    0.050420
#  3   0.680108    0.176471
#  4   0.543011    1.031513
#  5   0.142473    0.243697
#  6   0.814516    0.264706
#  7   0.357527    0.617647
#  8   0.327957    0.176471
#  9   0.282258    0.197479
#  10  0.626344    0.350840
#  11  0.766129    0.871849
#  12  0.852151    0.182773
#  13  0.360215    0.037815
#  14  0.685484    0.355042
#  15  0.260753    0.006303
#  16  0.733871    0.134454
#  17  0.849462    0.147059
#  18  0.432796    0.098739
#  19  0.752688    0.159664
#  20  0.559140    0.025210
# ...

# %% [markdown]
# <h2>Mean Normalization</h2>

# %%
# mean centering , have to code manually , used where we need centered data but then we use standardixation , so it is used rarely

# %% [markdown]
# <h2>
#     Max Abs Scaling
#
# </h2>

# %%
# Xi/Xmax , sklearn mein class hai MaxAbsScaler , useful where sparsed data(bhot jyada 0)

# %% [markdown]
# <h2>
#     Robust scaling
# </h2>

# %%
#Xi-Xmeadian /IQR (75 per. - 25per)

#robust to outliers

# %% [markdown]
# <h2>Normalization vs standardization</h2>

# %% [markdown]
# do we need feature scaling(when we know algo's internal working)

# %% [markdown]
# mosy algo are solved using standardization

# %% [markdown]
# Min MAx used when we know min max

# %% [markdown]
# Begineer use all
